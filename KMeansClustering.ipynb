# %%
import matplotlib.pyplot as plt 
from sklearn.datasets import make_blobs
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
X,y = make_blobs(n_samples=1000,centers=3,n_features=2)

# %%
X
# Out:
# array([[ 5.4882165 , -7.3171355 ],
#        [-0.5662324 , -3.61446279],
#        [ 4.42301699, -7.30328331],
#        ...,
#        [ 6.63892458, -6.86208002],
#        [ 5.08677322, -6.60702254],
#        [ 1.3400314 , -3.60954132]])

# %%
plt.scatter(X[:,0],X[:,1])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=12)

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
x_train_scaled = ss.fit_transform(X_train)

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for k in range(1,11):
    kMeans=KMeans(n_clusters=k,init='k-means++')
    kMeans.fit(x_train_scaled)
    wcss.append(kMeans.inertia_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 wcss = []
#       2 for k in range(1,11):
# ----> 3     kMeans=KMeans(n_clusters=k,init='k-means++')
#       4     kMeans.fit(x_train_scaled)
#       5     wcss.append(kMeans.inertia_)
#
# TypeError: 'KMeans' object is not callable

# %%
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.plot(range(1,11),wcss)
#       2 plt.xticks(range(1,11))
#       3 plt.xlabel("Number of Clusters")
#
# NameError: name 'wcss' is not defined

# %%
kMeans = KMeans(n_clusters=3,init='k_means++')

# %%
kMeans.fit_predict(x_train_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 kMeans.fit_predict(x_train_scaled)
#
# NameError: name 'kMeans' is not defined

# %%
# !pip install kneed

# %%
from kneed import KneeLocator

# %%
k1 = KneeLocator(range(1,11),wcss,curve="convex",direction="decreasing")

# %%
k1.elbow()

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_coefficients = []
for k in range(2,11):
    kmeans = KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(x_train_scaled)
    score=silhouette_score(x_train_scaled,kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
silhouette_coefficients
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 silhouette_coefficients
#
# NameError: name 'silhouette_coefficients' is not defined

# %%
plt.plot(range(1,11),silhouette_coefficients)
plt.xticks(range(1,11))
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.plot(range(1,11),silhouette_coefficients)
#       2 plt.xticks(range(1,11))
#       3 plt.xlabel("Number of Clusters")
#
# NameError: name 'silhouette_coefficients' is not defined
